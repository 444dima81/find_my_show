# %%
import pandas as pd

# %%
data = pd.read_csv('../data/data2.csv')

# %%
data.head()
# Out:
#                          page_url  \
# 0   https://myshows.me/view/7718/
# 1  https://myshows.me/view/11945/
# 2     https://myshows.me/view/45/
# 3      https://myshows.me/view/2/
# 4    https://myshows.me/view/187/
#
#                                            image_url            tvshow_title  \
# 0  https://media.myshows.me/shows/760/9/49/9492ce...                  Шерлок
# 1  https://media.myshows.me/shows/760/d/d1/dd10e6...          Игра престолов
# 2  https://media.myshows.me/shows/760/f/c3/fc37c3...      Сверхъестественное
# 3  https://media.myshows.me/shows/760/2/a9/2a9328...  Теория большого взрыва
# 4  https://media.myshows.me/shows/760/0/c2/0c2961...           Во все тяжкие
#
#                                          description
# 0  История о Шерлоке Холмсе и докторе Ватсоне в Л...
# 1  Игра Престолов — американский фэнтези-сериал, ...
# 2  Больше десяти лет назад это шоу начиналось, ка...
# 3  Теория большого взрыва это, уже ставший класси...
# ...
